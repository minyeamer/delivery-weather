# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ## 라이브러리 선언

# %%
import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %matplotlib inline

# 한글 폰트 선언
# !apt install fonts-nanum
# font_path = '/usr/share/fonts/truetype/baemin/BMDOHYEON.ttf'
# font_name = font_manager.FontProperties(fname=font_path, size=10).get_name()
# rc('font', family=font_name)

# %% [markdown]
# ## 데이터 불러오기

# %%
from weather_data import get_dataframe as get_weather

weather = get_weather('2019', directory='original_data/')
weather = weather.reset_index()

# %%
weather
# Out:
#       date  temp  cloud  rain  snow  wind
# 0    01-01  -5.0    3.4   0.0   0.0   2.1
# 1    01-02  -4.9    0.0   0.0   0.0   1.7
# 2    01-03  -3.5    0.1   0.0   0.0   1.4
# 3    01-04  -1.1    5.5   0.0   0.0   1.2
# 4    01-05  -2.8    0.5   0.0   0.0   2.2
# ..     ...   ...    ...   ...   ...   ...
# 360  12-27  -1.7    0.0   0.0   0.0   2.1
# 361  12-28   1.1    3.5   0.0   0.0   2.0
# 362  12-29   3.8    9.0   1.4   0.0   2.9
# 363  12-30   2.7    7.5   0.4   0.0   2.9
# 364  12-31  -7.9    1.3   0.0   0.0   3.1
#
# [365 rows x 6 columns]

# %%
# from weather_data import detach_month

# weather_day = detach_month(weather)

# %%
# weather_day

# %% [markdown]
# ## 평균온도 그래프
# - [seaborn.lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html)

# %%
weather['temp'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(np.diff(weather['temp'])) # 차분
plt.plot(weather['temp'])
plt.show()

# moving average (지수평활법 exponential moving average)

# %%
weather['rain'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(np.diff(weather['rain']))
plt.plot(weather['rain'])
plt.show()

# %% [markdown]
# ## 테스트 코드

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
# weather['score'] = sns.load_dataset('iris')
 
# Large bandwidth
sns.kdeplot(weather['score'], shade=True, bw=0.5, color="olive")
plt.show()
# Out:
# /shared-libs/python3.8/py/lib/python3.8/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
plt.hist(weather['score'], bins=np.linspace(0.99, 3.99, 4))
# Out:
# (array([131.,  73.,  41.]),
#  array([0.99, 1.99, 2.99, 3.99]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aeda0379-ef07-4599-92da-f5608bf4c48d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
